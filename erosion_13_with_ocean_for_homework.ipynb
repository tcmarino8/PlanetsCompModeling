# %%
## Import necessary packages
# On Macs use osx
# For Windows use qt
# %matplotlib qt
import ffmpeg
import numpy as np
from numpy.random import rand
from landscapeWithOcean import LandscapeWithOcean # Import methods from inside file landscapeWithOcean.py

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
def AddHill(Z,NX,NY,xx,yy,r,h):

    for x in range(NX):
        for y in range(NY):
            dx = np.mod(x-xx+NX/2,NX)-NX/2; # difference i-i0 but apply p.b.c. 
            dy = np.mod(y-yy+NY/2,NY)-NY/2;
            dr = np.sqrt(dx**2+dy**2);
            if (dr<r):
                Z[x,y] += h * (np.cos(dr/r*np.pi/2.0))**2;
    return Z

# %%
### Define simulation grid and initial conditions

NX = 35*2 #number of rows
NY = 35*2 #number of columns

d  = 5 # grid spacing in meters
dx = d # keep dx=dy for simplicity
dy = d

LX=NX*dx
LY=NY*dy

# small random features in topography to begin erosion
Z = rand(NX,NY)*0.1
for i in range(5):
    xx = rand()*NX
    yy = rand()*NY
    r  = (0.1+rand())*NX
    h  = (0.1+rand())*5
    Z = AddHill(Z,NX,NY,xx,yy,r,h)

for i in range(5):
    xx = rand()*NX
    yy = rand()*NY
    r  = (0.1+rand())*NX/2
    h  = (0.5+rand())*10
    Z = AddHill(Z,NX,NY,xx,yy,r,h)

x = np.arange(NX)
y = np.arange(NY)
X,Y = np.meshgrid(y,x) #strange that y goes first !!!
ZMaxOrg = np.max(Z)
#print(ZMaxOrg)

# %%
### Physical Parameters
K = 1.0e-6 # meters^(1-2m)/yr

D = 0.005 # m^2/yr

# uplift rate
# uplift = 0.03 / 600.
uplift = 0.0

# %%
### Model parameters

# Time step
dt = d**2 / D / 8. 
#dt = d**2 / D /16. #extra small steps 
print(' dt[years] = ',dt)

#Area exponent A^m, default m=1
m=4

#gradient exponent g^n, default n=1
n=1

#erosion threshold 
theta_c = 10
# Out:
#  dt[years] =  625.0

# %%
# Total simulation time
T = 1000.0 * 625.0

# total number of iterations
n_iter = int(np.round(T/dt))
print('Number of interation: ',n_iter)
# Out:
# Number of interation:  1000

# %%
# Initialize landscape 
ls = LandscapeWithOcean(NX,NY)

oceanLevelParameter=0.1  # what does this parameter do?
ls.ComputeOceanVolumeFromOceanLevelParameter(Z,NX,NY,oceanLevelParameter)

ls.pool_check(Z,NX,NY)
ls.A = np.zeros((NX,NY))
# Out:
# Minimum elevation           2.1110698683769775
# Maximum elevation           21.52335233433031
# Beach level                 4.052298114972311
# Ocean volume                421.65888211002056
# Percentage of ocean surface 10.10204081632653

# %%
# Set-up figure
def init_figure():
    fig = plt.figure(figsize=(12.,6.))
    plt.show()
    return fig

def update_figure():
        plt.clf()
        ax1 = fig.add_subplot(121,projection='3d')

        # use equal x-y aspect with an explicit vertical exageration
        vert_exag = 4.
        ax1.set_xlim3d(0,max(NX,NY))
        ax1.set_ylim3d(0,max(NX,NY))
        ax1.set_zlim3d(0,ZMaxOrg)

        ax1.set_title('Surface Relief')

#        surf = ax1.plot_surface(X,Y,Z, cmap = cm.terrain, rstride=1, cstride=1,
#                antialiased=False,linewidth=0)

        ZPlot = np.copy(Z)
        ZPlot[ZPlot<ls.ZBeachLevel] = ls.ZBeachLevel 
        ZPlot -= ls.ZBeachLevel
        ax1.plot_surface(X,Y,ZPlot, cmap = cm.terrain, rstride=1, cstride=1,
                antialiased=False,linewidth=0)

        ax2 = fig.add_subplot(122,aspect='equal')
        ax2.set_title('Elevation')

        #im = ax2.pcolor(Z,cmap=cm.terrain)
        im = ax2.pcolor(ZPlot,cmap=cm.coolwarm)
        cs = ax2.contour(ZPlot,6,colors='k')

        # Add a color bar which maps values to colors.
        cbar = fig.colorbar(im, shrink=0.5, aspect=5)
        # Add the contour line levels to the colorbar
        cbar.add_lines(cs)

        #plt.show()
        plt.draw()
        plt.pause(0.0001)

# %%
# Set up figure
fig = init_figure()
update_figure()
Znew = np.copy(Z)

for it in range(1,n_iter+1):
    
    ls.calculate_collection_area(Z,NX,NY)
    ls.A *= dx*dy
    
    for i in range(NX):
        iL = np.mod(i-1,NX) # normally i-1 but observe p.b.c.
        iR = np.mod(i+1,NX) # normally i+1 but observe p.b.c.

        for j in range(NY):
            jD = np.mod(j-1,NY) # normally j-1 but observe p.b.c.
            jU = np.mod(j+1,NY) # normally j+1 but observe p.b.c.
  
            if ls.ocean[i,j]>0:
                Psi_z  = 0;
                Phi_z  = 0;
            else:
                if ls.drain[i,j]>0: #this cell is a drain
                    s1 = (Z[iR,j]  - Z[iL,j] )/(2.*dx)
                    s2 = (Z[i,jU]  - Z[i,jD] )/(2.*dy)
                    s3 = (Z[iR,jD] - Z[iL,jU])/(2. * np.sqrt( dx**2 + dy**2) )
                    s4 = (Z[iR,jU] - Z[iL,jD])/(2. * np.sqrt( dx**2 + dy**2) )
                    gradient = (np.sqrt(s1**2 + s2**2) + np.sqrt(s3**2 + s4**2))/2.
                    Psi_z = K * ( ls.A[i,j]**m * gradient**n - theta_c)            

                elif ls.drainage[i,j]>0: #this cell is a drainage point (it drains a pool)
                
                    if (Z[i,j]>=Z[iR,j]) and ls.pool[iR,j]!=ls.drainage[i,j]: 
                        gradient = (Z[i,j]-Z[iR,j])/dx #pool is on my left, I drain to the right, use this gradiant
                    elif (Z[i,j]>=Z[iL,j]) and ls.pool[iL,j]!=ls.drainage[i,j]:
                        gradient = (Z[i,j]-Z[iL,j])/dx
                    elif (Z[i,j]>=Z[i,jU]) and ls.pool[i,jU]!=ls.drainage[i,j]:
                        gradient = (Z[i,j]-Z[i,jU])/dy
                    elif (Z[i,j]>=Z[i,jD]) and ls.pool[i,jD]!=ls.drainage[i,j]:
                        gradient = (Z[i,j]-Z[i,jD])/dy
                    else:
                        gradient = 0.02 # ??? This does happen (maybe when two pools merge)
                    Psi_z = K * ( ls.A[i,j]**m * gradient**n - theta_c)
                
                else: #this cell is a pool, assume it has some mass diffusion but no erosion!
                    Psi_z = 0.
                
                if (Psi_z<0):
                    Psi_z = 0. 

                # diffusion term
                Phi_z = D * ( (Z[iR,j] - 2.*Z[i,j] + Z[iL,j]) / dx**2 \
                            + (Z[i,jU] - 2.*Z[i,j] + Z[i,jD]) / dx**2 )
           
            Znew[i,j] = Z[i,j] + (Phi_z - Psi_z + uplift )*dt  

            dZdt= (Znew[i,j] - Z[i,j]) / dt
            CFL = abs(dZdt) * dt / min(dx,dy)
            if (CFL>1.0):
                print('\nWarning: Time step of',dt,'is probably too large. Safer would be:',dt/CFL)
            
            if (Znew[i,j]<0.):
                Znew[i,j] = 0. # yes, this does happen at the boundary when kept at zero
    
    #Znew[0,:] = 0.0 # resets front boundary to 0
    Z = np.copy(Znew)
    
    ls.pool_check(Z,NX,NY)

    if (np.mod(it,10)==0): 
        print(it,end='')
        update_figure()
        print(' Ocean level=',ls.ZBeachLevel,' Ocean surface fraction=',100*ls.AOcean/(NX*NY));
    else:
        print('.',end='')

update_figure()
print(' Simulation finished.')
# Out:
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.004332571805378977
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0005649060691367907
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0002608446489723654
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0005542849713467696
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 6.072153246357184e-05
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 2.860491681239325e-05
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 5.625757296088314e-05
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 7.901152639011027e-05
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 4.813714799521722e-05
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.001901682913267765
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0018993673933517471
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.006410360534385073
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.01667865795901229
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.008137426590379592
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.004776855426662028
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.002502254574661856
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.001964869105731764
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0027105080811309105
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.005315976050159866
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.007965740597678976
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.017429786346856668
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.023024191592063047
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.02727539894760742
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.03854074832353789
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.05273656053526221
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.03974040262402358
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.041652986846649004
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.05700700913388945
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0872641164318269
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.1338286339048519
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.211177126978459
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.32131738151565026
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.7705961636054809
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 2.408946069757375
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.9189445089549476
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.6604596150676232
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.3576893359770579
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.25538504678542606
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.2431309316992026
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.16704420799904124
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.22064440753877004
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.39225501265570184
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.1083674369815163
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.12849153710925323
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.22252795818182364
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.6834062499138299
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.5259045234797578
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.18089836545592872
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.23727687145608364
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.19931162387718562
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.3012326320632399
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.09253465304679685
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.02706220631680214
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.017625578645002977
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.017954215711849714
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.017677957023297178
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.015462900861654813
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0023101572670522056
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0019448309761771272
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 1.80637653731138e-06
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 1.4661920296613794e-06
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 2.4857206029945795e-06
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 3.2481329379759177e-06
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 3.120531278936179e-06
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 7.620579419487196e-06
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 8.300936678665126e-06
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 1.2837293820660138e-05
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.00019957223862858902
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 1.1758665708465088e-05
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.004357191629284623
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0015887121507373672
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0017006578460521946
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.005596314184024362
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.004092949992648879
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0053544790213282826
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.006785540032965631
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.011646609785695032
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0207881900272611
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.02054780724081033
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.023928901853868253
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.018287141845620688
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.015320229942369592
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.0385911681329485
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.04288007323217471
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.04178135413481377
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.05399731430204634
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.06257398719082033
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.07691706452318513
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.11635284803886459
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.18172334126072268
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.3699617846042986
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.7441897460360184
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 1.6007793266546213
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 5.944640389047494
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 1.5415474661665343
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 1.1731152695121414
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.5689358177716662
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.40036106414871886
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.39771506794318934
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.3230327246974689
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.613392416495328
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.22516545062659052
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.04157248008901269
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.025937549033841285
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.020766613361795486
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.021999958450479598
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.08312199181774156
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.08395106752731334
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.09557779272325906
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.06991401107764457
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.04230411849115068
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.05729192111012803
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.06939553214316038
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 42.638223215635335
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 42.767879610312946
# .
# Warning: Time step of 625.0 is probably too large. Safer would be: 52.259497338493645
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 53.60622203188784
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 54.68951270516031
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 45.73401614887716
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 53.797427161657
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 135.73118659163748
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 52.68109217211931
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 0.032691953757701446
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 137.75885878228652
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 52.282315635973774
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 46.72805308783554
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 100.36088492641623
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 54.26448397784655
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 53.684997141669136
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 139.3710003468637
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 52.32013783955713
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 46.11612555557912
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 54.92633703977419
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 45.78645140577483
# .
# Warning: Time step of 625.0 is probably too large. Safer would be: 53.54841047560738
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 47.01736473004065
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 1.5977901526009997
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 53.852014117454914
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 47.22133462695386
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 105.20784098759376
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 56.26678173066164
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 47.032068683246344
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 46.87432569352807
# .
# Warning: Time step of 625.0 is probably too large. Safer would be: 111.66260921147833
#
# Warning: Time step of 625.0 is probably too large. Safer would be: 111.67882197083559
# 10 Ocean level= 0.09590682782990337  Ocean surface fraction= 100.0
# .........20 Ocean level= 0.09590682782990337  Ocean surface fraction= 100.0
# .........30 Ocean level= 0.09590682782990337  Ocean surface fraction= 100.0
# .........40 Ocean level= 0.09590682782990337  Ocean surface fraction= 100.0
# .........50 Ocean level= 0.09590682782990337  Ocean surface fraction= 100.0
# .........60 Ocean level= 0.09590682782990337  Ocean surface fraction= 100.0
# .........70 Ocean level= 0.09590682782990337  Ocean surface fraction= 100.0
# .........80 Ocean level= 0.09590682782990337  Ocean surface fraction= 100.0
# .........90 Ocean level= 0.09590682782990337  Ocean surface fraction= 100.0
# .........100 Ocean level= 0.09590682782990337  Ocean surface fraction= 100.0
# .........110
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\Homeworks\HW9\erosion_13_with_ocean_for_homework.ipynb Cell 9 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X11sZmlsZQ%3D%3D?line=69'>70</a> if (np.mod(it,10)==0):
#      <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X11sZmlsZQ%3D%3D?line=70'>71</a>     print(it,end='')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X11sZmlsZQ%3D%3D?line=71'>72</a>     update_figure()
#      <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X11sZmlsZQ%3D%3D?line=72'>73</a>     print(' Ocean level=',ls.ZBeachLevel,' Ocean surface fraction=',100*ls.AOcean/(NX*NY));
#      <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X11sZmlsZQ%3D%3D?line=73'>74</a> else:
#
# c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\Homeworks\HW9\erosion_13_with_ocean_for_homework.ipynb Cell 9 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X11sZmlsZQ%3D%3D?line=32'>33</a> cs = ax2.contour(ZPlot,6,colors='k')
#      <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X11sZmlsZQ%3D%3D?line=34'>35</a> # Add a color bar which maps values to colors.
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X11sZmlsZQ%3D%3D?line=35'>36</a> cbar = fig.colorbar(im, shrink=0.5, aspect=5)
#      <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X11sZmlsZQ%3D%3D?line=36'>37</a> # Add the contour line levels to the colorbar
#      <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X11sZmlsZQ%3D%3D?line=37'>38</a> cbar.add_lines(cs)
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\figure.py:1310, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1306 NON_COLORBAR_KEYS = ['fraction', 'pad', 'shrink', 'aspect', 'anchor',
#    1307                      'panchor']
#    1308 cb_kw = {k: v for k, v in kwargs.items() if k not in NON_COLORBAR_KEYS}
# -> 1310 cb = cbar.Colorbar(cax, mappable, **cb_kw)
#    1312 if not userax:
#    1313     self.sca(current_ax)
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\_api\deprecation.py:384, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     379 @functools.wraps(func)
#     380 def wrapper(*inner_args, **inner_kwargs):
#     381     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     382         # Early return in the simple, non-deprecated case (much faster than
#     383         # calling bind()).
# --> 384         return func(*inner_args, **inner_kwargs)
#     385     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     386     if is_varargs and arguments.get(name):
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\colorbar.py:402, in Colorbar.__init__(self, ax, mappable, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, filled, extendfrac, extendrect, label, location)
#     399 self.ticklocation = ticklocation
#     401 self.set_label(label)
# --> 402 self._reset_locator_formatter_scale()
#     404 if np.iterable(ticks):
#     405     self._locator = ticker.FixedLocator(ticks, nbins=len(ticks))
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\colorbar.py:1173, in Colorbar._reset_locator_formatter_scale(self)
#    1167 def _reset_locator_formatter_scale(self):
#    1168     """
#    1169     Reset the locator et al to defaults.  Any user-hardcoded changes
#    1170     need to be re-entered if this gets called (either at init, or when
#    1171     the mappable normal gets changed: Colorbar.update_normal)
#    1172     """
# -> 1173     self._process_values()
#    1174     self._locator = None
#    1175     self._minorlocator = None
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\colorbar.py:1107, in Colorbar._process_values(self)
#    1105     self.norm.vmin = 0
#    1106     self.norm.vmax = 1
# -> 1107 self.norm.vmin, self.norm.vmax = mtransforms.nonsingular(
#    1108     self.norm.vmin, self.norm.vmax, expander=0.1)
#    1109 if (not isinstance(self.norm, colors.BoundaryNorm) and
#    1110         (self.boundaries is None)):
#    1111     b = self.norm.inverse(b)
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\colors.py:1250, in Normalize.vmin(self, value)
#    1248 if value != self._vmin:
#    1249     self._vmin = value
# -> 1250     self._changed()
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\colors.py:1278, in Normalize._changed(self)
#    1273 def _changed(self):
#    1274     """
#    1275     Call this whenever the norm is changed to notify all the
#    1276     callback listeners to the 'changed' signal.
#    1277     """
# -> 1278     self.callbacks.process('changed')
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 if func is not None:
#     308     try:
# --> 309         func(*args, **kwargs)
#     310     # this does not capture KeyboardInterrupt, SystemExit,
#     311     # and GeneratorExit
#     312     except Exception as exc:
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\cm.py:665, in ScalarMappable.changed(self)
#     660 def changed(self):
#     661     """
#     662     Call this whenever the mappable is changed to notify all the
#     663     callbackSM listeners to the 'changed' signal.
#     664     """
# --> 665     self.callbacks.process('changed', self)
#     666     self.stale = True
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 if func is not None:
#     308     try:
# --> 309         func(*args, **kwargs)
#     310     # this does not capture KeyboardInterrupt, SystemExit,
#     311     # and GeneratorExit
#     312     except Exception as exc:
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\colorbar.py:514, in Colorbar.update_normal(self, mappable)
#     511     self.norm = mappable.norm
#     512     self._reset_locator_formatter_scale()
# --> 514 self._draw_all()
#     515 if isinstance(self.mappable, contour.ContourSet):
#     516     CS = self.mappable
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\colorbar.py:554, in Colorbar._draw_all(self)
#     552 self.vmin, self.vmax = self._boundaries[self._inside][[0, -1]]
#     553 # Compute the X/Y mesh.
# --> 554 X, Y = self._mesh()
#     555 # draw the extend triangles, and shrink the inner axes to accommodate.
#     556 # also adds the outline path to self.outline spine:
#     557 self._do_extends()
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\matplotlib\colorbar.py:1144, in Colorbar._mesh(self)
#    1142         y = self.norm.inverse(y)
#    1143 self._y = y
# -> 1144 X, Y = np.meshgrid([0., 1.], y)
#    1145 if self.orientation == 'vertical':
#    1146     return (X, Y)
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\numpy\lib\function_base.py:5163, in meshgrid(copy, sparse, indexing, *xi)
#    5160     output = np.broadcast_arrays(*output, subok=True)
#    5162 if copy:
# -> 5163     output = [x.copy() for x in output]
#    5165 return output
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\numpy\lib\function_base.py:5163, in <listcomp>(.0)
#    5160     output = np.broadcast_arrays(*output, subok=True)
#    5162 if copy:
# -> 5163     output = [x.copy() for x in output]
#    5165 return output
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\EPSvenv\Lib\site-packages\numpy\ma\core.py:2572, in _arraymethod.<locals>.wrapped_method(self, *args, **params)
#    2571 def wrapped_method(self, *args, **params):
# -> 2572     result = getattr(self._data, funcname)(*args, **params)
#    2573     result = result.view(type(self))
#    2574     result._update_from(self)
#
# KeyboardInterrupt:

# %% [markdown]
# #1
#
# Upon observation of the starter code, we are building a landscape that comes out of the ocean. This changes things up from the lab since not every part of our map is land, so not every part partakes in the erosion process. The ocean is essentially a large pool however it never leaks out as there is no overflow point.
#
# Ocean level parameter is essentially the sea level. AKA you are at the beach at you are at 0 elevation below sea level. This is the threshold where land becomes land above water as opposed to being underwater.
#
# The ocean level is seeming decreasing after each iteration. Inversely, the ocean surface fraction is increasing. This to me is a little confusing to me as you would expect a direct relation of the two variables however it is saying that as the land erodes into the ocean, the sea starts a little lower since it is being offset by more landmass?

# %% [markdown]
# #2: CREATING MY OWN LANDSCAPE

# %% [markdown]
# Being from a coastal town, I see lots of erosion occur on the cliffs that sit on the beaches. As time progresses, houses are lost, plots of land become less valuable and people are sometimes crushed. These events can occur more frequent than the erosion that we are seeing because of frequent bluff collapses, constant erosion by waves and poor sedimentary material that cannot withstand rain. However I thought I would craft a hillside/clif of my own and see it erode using the same methods as we have been learning in class.

# %%
### Define simulation grid and initial conditions

NX = 35*2 #number of rows
NY = 3*2 #number of columns

d  = 5 # grid spacing in meters
dx = d # keep dx=dy for simplicity
dy = d

LX=NX*dx
LY=NY*dy

# %%
### Define simulation grid and initial conditions

fig = init_figure()


# Create a cliff topography: designing a fucntion that fills in data points with a height that fills in a pattern like that of a quadratic equation.
Z = rand(NX,NY)*0.1
for x in range(7,NX):
    for y in range(NY-20):
        if (.5*(x-8))**2 - y < 0:
            Z[x, y] = 800/(.75*(x+10))
        elif ((.5*(x-8))**2 - y > 0) and ((.5*(x-8))**2 - y < 40):
            Z[x, y] = 600/(x)
        else:
            Z[x,y] = 45-x
Z[:7, :] = 62



x = np.arange(NX)
y = np.arange(NY)
X,Y = np.meshgrid(y,x) #strange that y goes first !!!
ZMaxOrg = np.max(Z)
update_figure()

# %%
### Physical Parameters
K = 1.0e-6 # meters^(1-2m)/yr

D = 0.005 # m^2/yr

# uplift rate
# uplift = 0.03 / 600.
uplift = .001

### Model parameters

# Time step
dt = d**2 / D / 8. 
#dt = d**2 / D /16. #extra small steps 
print(' dt[years] = ',dt)

#Area exponent A^m, default m=1
m=1

#gradient exponent g^n, default n=1
n=1

#erosion threshold 
theta_c = 10
# Out:
#  dt[years] =  625.0

# %%
# Set up figure
fig = init_figure()
update_figure()
Znew = np.copy(Z)

for it in range(1,n_iter+1):
    
    ls.calculate_collection_area(Z,NX,NY)
    ls.A *= dx*dy
    
    for i in range(NX):
        iL = np.mod(i-1,NX) # normally i-1 but observe p.b.c.
        iR = np.mod(i+1,NX) # normally i+1 but observe p.b.c.

        for j in range(NY):
            jD = np.mod(j-1,NY) # normally j-1 but observe p.b.c.
            jU = np.mod(j+1,NY) # normally j+1 but observe p.b.c.
  
            if ls.ocean[i,j]>0:
                Psi_z  = 0;
                Phi_z  = 0;
            else:
                if ls.drain[i,j]>0: #this cell is a drain
                    s1 = (Z[iR,j]  - Z[iL,j] )/(2.*dx)
                    s2 = (Z[i,jU]  - Z[i,jD] )/(2.*dy)
                    s3 = (Z[iR,jD] - Z[iL,jU])/(2. * np.sqrt( dx**2 + dy**2) )
                    s4 = (Z[iR,jU] - Z[iL,jD])/(2. * np.sqrt( dx**2 + dy**2) )
                    gradient = (np.sqrt(s1**2 + s2**2) + np.sqrt(s3**2 + s4**2))/2.
                    Psi_z = K * ( ls.A[i,j]**m * gradient**n - theta_c)            

                elif ls.drainage[i,j]>0: #this cell is a drainage point (it drains a pool)
                
                    if (Z[i,j]>=Z[iR,j]) and ls.pool[iR,j]!=ls.drainage[i,j]: 
                        gradient = (Z[i,j]-Z[iR,j])/dx #pool is on my left, I drain to the right, use this gradiant
                    elif (Z[i,j]>=Z[iL,j]) and ls.pool[iL,j]!=ls.drainage[i,j]:
                        gradient = (Z[i,j]-Z[iL,j])/dx
                    elif (Z[i,j]>=Z[i,jU]) and ls.pool[i,jU]!=ls.drainage[i,j]:
                        gradient = (Z[i,j]-Z[i,jU])/dy
                    elif (Z[i,j]>=Z[i,jD]) and ls.pool[i,jD]!=ls.drainage[i,j]:
                        gradient = (Z[i,j]-Z[i,jD])/dy
                    else:
                        gradient = 0.02 # ??? This does happen (maybe when two pools merge)
                    Psi_z = K * ( ls.A[i,j]**m * gradient**n - theta_c)
                
                else: #this cell is a pool, assume it has some mass diffusion but no erosion!
                    Psi_z = 0.
                
                if (Psi_z<0):
                    Psi_z = 0. 

                # diffusion term
                Phi_z = D * ( (Z[iR,j] - 2.*Z[i,j] + Z[iL,j]) / dx**2 \
                            + (Z[i,jU] - 2.*Z[i,j] + Z[i,jD]) / dx**2 )
           
            Znew[i,j] = Z[i,j] + (Phi_z - Psi_z + uplift )*dt  

            dZdt= (Znew[i,j] - Z[i,j]) / dt
            CFL = abs(dZdt) * dt / min(dx,dy)
            if (CFL>1.0):
                print('\nWarning: Time step of',dt,'is probably too large. Safer would be:',dt/CFL)
            
            if (Znew[i,j]<0.):
                Znew[i,j] = 0. # yes, this does happen at the boundary when kept at zero
    
    #Znew[0,:] = 0.0 # resets front boundary to 0
    Z = np.copy(Znew)
    
    ls.pool_check(Z,NX,NY)

    if (np.mod(it,10)==0): 
        print(it,end='')
        update_figure()
        print(' Ocean level=',ls.ZBeachLevel,' Ocean surface fraction=',100*ls.AOcean/(NX*NY));
    else:
        print('.',end='')

update_figure()
print(' Simulation finished.')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\Homeworks\HW9\erosion_13_with_ocean_for_homework.ipynb Cell 16 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> Znew = np.copy(Z)
#       <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> for it in range(1,n_iter+1):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a>     ls.calculate_collection_area(Z,NX,NY)
#       <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a>     ls.A *= dx*dy
#      <a href='vscode-notebook-cell:/c%3A/Users/Tyler%20Marino/OneDrive/Desktop/EPS109/Homeworks/HW9/erosion_13_with_ocean_for_homework.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a>     for i in range(NX):
#
# File c:\Users\Tyler Marino\OneDrive\Desktop\EPS109\Homeworks\HW9\landscapeWithOcean.py:60, in LandscapeWithOcean.calculate_collection_area(self, Z, NX, NY)
#      58 #compute fraction of flow to all lower cells
#      59 zsum = 0
# ---> 60 if (Z[x,y]>Z[xU,y]):
#      61     zsum = zsum+Z[x,y]-Z[xU,y]
#      62 if (Z[x,y]>Z[xD,y]):
#
# IndexError: index 69 is out of bounds for axis 1 with size 6

# %% [markdown]
# #3:
# An increase in D will smooth out the erosion of land it seems. I upped it by a magnitude of 10 and it produced a very appealing slope and the 2d topographical map was very smooth/rounded.
#
# An increase in uplift seemingly repopulated the ocean with landmass. This doesnt seem to realistic, however it did make a nice chanel which remebeled stream flow path down the side of the cliff when uplift was equal to .5
#
# the m affects the weight of the current "drainage area" associated with the erosion process, increasing m would then make the system much more conformed(not much diversity)
#
# The n affects the weight of the gradiant in the erosion model. An increase would make it converge erode towards the lower land much faster tahn the higher land.
#
# For both the n and the m, a decrease would lead to the inverse result as described above.
